# %% [markdown]
# # Data Exploration of the Rhine water level in Ludwigshafen

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
CB91_Blue = '#2CBDFE'
CB91_Green = '#47DBCD'
color_list = [CB91_Blue, 'red']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)

# %%
data = pd.read_csv('data/Kaub_Level_Since_2013_updated_v2.csv')
path = 'results/' # path for saving figures

# %% [markdown]
# First, I'm going to get a basic overview of the data. That is, getting a glimpse in the first and last parts of the data and getting basic statistical information.

# %%
data.head()
# Out:
#          date  level
# 0  2013-01-01    510
# 1  2013-01-02    461
# 2  2013-01-03    414
# 3  2013-01-04    378
# 4  2013-01-05    351

# %%
data.tail()
# Out:
#             date  level
# 3261  2021-12-06    191
# 3262  2021-12-07    245
# 3263  2021-12-08    228
# 3264  2021-12-09    202
# 3265  2021-12-10    197

# %%
data.describe()
# Out:
#              level
# count  3266.000000
# mean    205.135028
# std     102.576561
# min      20.000000
# 25%     137.000000
# 50%     186.000000
# 75%     252.000000
# max     713.000000

# %%
data.median()
# Out:
# <ipython-input-7-135339ac59ce>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# level    186.0
# dtype: float64

# %%
data['level'].var()
# Out:
# 10521.950827824687

# %% [markdown]
# The median is a little bit off the mean, with mean > median, this suggests that there are more or stronger outliers in the maximum range.

# %%
data.isna().any()
# Out:
# date     False
# level    False
# dtype: bool

# %%
x = data[data.duplicated(['date'])].index
print(f' Show duplicate values, if any: {x.values}')
# Out:
#  Show duplicate values, if any: []

# %%
df_index = data.set_index(data['date'])
df_index.index = pd.to_datetime(df_index.index)
dates_original = pd.date_range(start=data['date'].iloc[0], end=data['date'].iloc[-1]).difference(df_index.index)
print(f'There are a total of {len(dates_original)} dates missing.')
print('These are the missing dates on the updated data, if any: \n', dates_original.values)
# Out:
# There are a total of 0 dates missing.
# These are the missing dates on the updated data, if any:
#  []

# %%
data.hist(legend='true')
plt.xlabel('Rhine water level')
plt.ylabel('Number of data points')
plt.title('Histogram of rhine water levels')
plt.savefig(path + 'histogramm.png', dpi=300)

# %% [markdown]
# In the following, I will show the data with linear regression used on it to see an approximate trend.

# %%
plt.figure(1)
data.plot(x='date', y='level')
m, b = np.polyfit(np.arange(len(data.index)), data['level'], 1)
plt.plot(np.arange(len(data.index)), m * np.arange(len(data.index)) + b)
plt.xlabel('Year')
plt.ylabel('Water Level')
plt.title('Water level of Rhine in Ludwigshafen over time')
plt.legend(['Water Levels', 'Linear Regression'], frameon=False)
plt.locator_params(axis='x', nbins=6)
plt.savefig(path + 'data_plot_linear_reg.png', dpi=300)
print('m is: {}; b is: {}'.format(m, b))
# Out:
# m is: -0.014594448509747688; b is: 228.96046474880737

# %% [markdown]
# So according to linear regression (regardless if it can be realistically applied to this data or not), there seems to be a slight downward trend in time.

# %% [markdown]
# Next up, I'm gonna use seasonal_decompose from the statsmodel library, since intuitively, water levels should have a seasonal component to it. If one looks closely at the data, one can notice at least some seasonal components.

# %%
result_add = seasonal_decompose(x=data['level'], model='multiplicative', period=91)

# %%
plt.rc("figure", figsize=(20,18))
result_add.plot()
plt.savefig(path + 'seasonality.png', dpi=300)
plt.show()

# %% [markdown]
# There does not seem to be an obvious trend in the data, but there is a strong seasonal component to the data even though the residuals are sometimes strong. The variance in the data is high.

# %% [markdown]
# Show distribution of data by using a Box Plot. The Box shows the quartiles of the dataset, the whiskers show the rest of the distribution. The points at the end are points that are considered outliers using a method that is a function of the interquartile range.

# %%
plt.figure(2)
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data['level'])
plt.savefig(path + 'box_plot.png', dpi=300)

# %% [markdown]
# The Box Plot shows, that while most of the time, the rhine water level is at around 130 to 250, the level sometimes rises thrice the size of the average. There are also only outliers at a higher water level, none at a lower level.

# %% [markdown]
# Split data according to months in order to see the variation in water levels per month since intuitively, the month is of great concern when looking at water levels

# %%
def split_data_monthly(data):
    monthly_data = data.copy()
    monthly_data['month'] = pd.DatetimeIndex(data['date']).month_name()
    monthly_median = monthly_data.groupby('month').agg(
        {'level': np.median}).reset_index()
    monthly_mean = monthly_data.groupby('month').agg({'level': np.mean}).reset_index()
    return monthly_mean, monthly_median

monthly_mean, monthly_median = split_data_monthly(data)

# %% [markdown]
# Sorts the months in the right order for the plot later on

# %%
months = ["January", "February", "March", "April", "May", "June", 
          "July", "August", "September", "October", "November", "December"]

monthly_mean['month'] = pd.Categorical(monthly_mean['month'], categories=months, ordered=True)
monthly_median['month'] = pd.Categorical(monthly_median['month'], categories=months, ordered=True)

# %%
plt.figure(3, figsize=(20,6))
sns.barplot(x="month", y="level", data=monthly_median).set(title='Median of Rhine Water Levels per Month')
plt.savefig(path + 'median_month.png', dpi=300)
plt.figure(4, figsize=(20,6))
sns.barplot(x="month", y="level", data=monthly_mean).set(title='Mean of Rhine Water Levels per Month')
plt.savefig(path + 'mean_month.png', dpi=300)

# %% [markdown]
# The mean seems to be higher than the median in every month. To get a better view of this difference, the next bar plot plots the difference of the mean to the median each month

# %%
monthly_mean = monthly_mean.assign(diff_water_level = monthly_mean['level'] - monthly_median['level'])

# %%
plt.figure(5)
sns.barplot(x='month', y='diff_water_level', data=monthly_mean).set(title='Difference of Mean to Median')
plt.savefig(path + 'difference_median_mean.png', dpi=300)

# %% [markdown]
# Now, one can see the differences of the median to the mean more clearly. In every month, mean > median, but more importantly, the difference varies by month, sometimes strongly. The chart suggests, that the there are less or less extreme outliers during august-november.

# %%
quantile1, quantile3 = data['level'].quantile([0.25, 0.75])
IQR = quantile3 - quantile1
lower = quantile1 - (1.5 * IQR)
upper = quantile3 + (1.5 * IQR)
outlier = []
outlier_upper = []
outlier_lower = []
for level in data['level']:
    if level < lower or level > upper:
        outlier.append(level)
    if level > upper:
        outlier_upper.append(level)
    if level < lower:
        outlier_lower.append(level)
print('There are {} outliers (:= outside of the 25% and 75% quantile) in the data from a total of {} data points. \nThat makes {}% of the data outliers'.format(
    len(outlier), len(data['level']), round(len(outlier) / len(data['level']) * 100, 3)))
print('Of these, there are {} smaller than the 25 percentile, and {} bigger than the 75 percentile'.format(len(outlier_lower), len(outlier_upper)))
# Out:
# There are 122 outliers (:= outside of the 25% and 75% quantile) in the data from a total of 3266 data points.
# That makes 3.735% of the data outliers
# Of these, there are 0 smaller than the 25 percentile, and 122 bigger than the 75 percentile

# %%
plt.figure(6)
plt.bar(np.arange(2), [len(outlier_lower), round(len(outlier) / len(data['level']) * 100, 3)])
plt.title('Percentage of lower vs upper outliers')
plt.xlabel('Kind of outlier')
plt.ylabel('Percentage')
plt.xticks(np.arange(2), ['Lower', 'Upper'])
plt.savefig(path + 'outliers.png', dpi=300)
